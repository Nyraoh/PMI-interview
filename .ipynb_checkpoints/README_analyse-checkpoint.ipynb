# %%
import requests
from bs4 import BeautifulSoup
import csv
from collections import deque
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd 
import demoji

# %%
data = pd.read_csv("product_huff_puffer - Copie.csv",sep=';')

# %%
data.head()
# Out:
#                            product  \
# 0   candy-king-air-disposable-vape
# 1        daze-egge-disposable-vape
# 2      daze-ohmlet-disposable-vape
# 3  elfbar-airo-max-disposable-vape
# 4   elf-bar-bc5000-disposable-vape
#
#                                              options  average_score  \
# 0  [{'option': 'BlueRazz Straws', 'price': 14.99}...            4.4
# 1  [{'option': '7obacco', 'price': 11.99}, {'opti...            4.7
# 2  [{'option': 'Blueberry Cake', 'price': 15.99},...            4.6
# 3  [{'option': 'Banana Pineapple', 'price': 14.99...            4.6
# 4  [{'option': 'Beach Day', 'price': 14.99}, {'op...            4.8
#
#    recommand                                     specifications  \
# 0       86.0  ['11.0 mL per e-cigarette', '5% nicotine by we...
# 1       90.0  ['7.0 mL per e-cigarette', '5% nicotine by wei...
# 2       88.0  ['15.0 mL per e-cigarette', '5% nicotine by we...
# 3       92.0  ['13.0 mL of e-liquid per e-cigarette', 'Appro...
# 4       97.0  ['13.0 mL per e-cigarette', '5% nicotine by we...
#
#                                      package_content  \
# 0   ['1 X\xa0Candy King Air Disposable E-Cigarette']
# 1        ['1 X\xa0Daze Egge Disposable E-Cigarette']
# 2         ['1 X\xa0Daze Ohmlet Disposable\xa0E-Cig']
# 3  ['1 X\xa0Elf Bar Airo Max Disposable E-Cigaret...
# 4         ['1 X\xa0Elf Bar BC5000 Disposable E-Cig']
#
#                                          ingredients  nb_review  \
# 0  ['• USP Grade Propylene Glycol (60%)', '• USP ...        125
# 1  ['• Propylene Glycol (PG)', '• Vegetable Glyce...        173
# 2  ['• Propylene Glycol (PG)', '• Vegetable Glyce...        240
# 3  ['• Vegetable Glycerin (VG)', '• Propylene Gly...         79
# 4  ['• Vegetable Glycerin (VG)', '• Propylene Gly...        930
#
#                   scores_distribution  \
# 0    {5: 81, 4: 27, 3: 9, 2: 5, 1: 3}
# 1  {5: 135, 4: 21, 3: 14, 2: 3, 1: 0}
# 2  {5: 183, 4: 29, 3: 17, 2: 6, 1: 5}
# 3    {5: 60, 4: 13, 3: 4, 2: 1, 1: 1}
# 4  {5: 832, 4: 71, 3: 17, 2: 5, 1: 5}
#
#                                caracteristics_scores  \
# 0  {'flavor': 86.0759493670886, 'sweetness': 77.8...
# 1  {'flavor': 87.05882352941177, 'sweetness': 74....
# 2  {'flavor': 88.6094674556213, 'sweetness': 77.8...
# 3  {'flavor': 90.18987341772151, 'sweetness': 82....
# 4  {'flavor': 94.391785150079, 'sweetness': 84.99...
#
#                                              reviews
# 0  ['Tastes just like the candy!', 'Decent', "Gre...
# 1  ['Really love the service with these guys! The...
# 2  ['Good flavor long lasting.', "It's my only ch...
# 3  ['This is so good! Tastes exactly like Hawaiia...
# 4  ['Flavor was good', 'Great flavor. Not to swee...

# %%
import ast
from collections import Counter

# %%
def str_to_structured (data):
    for column in data.columns :
        if data[column].dtype == object :
            data[column] = data[data['nb_review']>0][column].apply(ast.literal_eval)
    return data

# %%
data.loc[:, data.columns != 'product'] = str_to_structured(data.loc[:, data.columns != 'product'])
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_11960\4135636802.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[data['nb_review']>0][column].apply(ast.literal_eval)

# %%
def most_commun_words (texts,n):
    # Join all the texts together into a single string
    all_text = " ".join(texts)

    # Split the string into individual words
    words = all_text.split()
    
    # Words to remove
    words_to_remove = ['the', 'and', 'I','a','it','is','i','to','of','was','but','this','are','my','for']

    # Remove specific words from the list of words
    words = [word for word in words if word.lower() not in words_to_remove]
    
    # Count the frequency of each word
    word_counts = Counter(words)

    # Get the two most common words and their frequencies
    most_common_words = word_counts.most_common(n)
    return most_common_words

# %%
data['most_commun_words'] = data[data['nb_review']>0]["reviews"].apply(lambda x : most_commun_words(x,5))

# %%
import matplotlib.pyplot as plt

def show_most_commun_words (data) :
    # Initialize an empty dictionary to store the word counts
    word_counts = {}

    # Loop through each sublist in the input data
    for sublist in data:
        # Loop through each tuple in the sublist
        for word, count in sublist:
            # Add the count to the existing count for the word, or initialize the count to zero
            word_counts[word] = word_counts.get(word, 0) + count

    # Sort the word_counts dictionary by count in descending order
    word_counts = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

    # Get the list of words and their counts
    words = [x[0] for x in word_counts]
    counts = [x[1] for x in word_counts]

    # Set the size of the figure
    fig, ax = plt.subplots(figsize=(10, 8))

    # Create a bar chart of the summed count of each word
    ax.bar(words[:20], counts[:20])
    ax.set_xlabel('Word')
    ax.set_ylabel('Count')
    ax.set_title('Summed Count of Words')
    plt.show()

# %%
show_most_commun_words(data[data['nb_review']>0]['most_commun_words'])

# %%
def best_caracteristic (caracterictics):
    caracterictics_score = sorted(caracterictics.items(), key=lambda x: x[1], reverse=True)
    return caracterictics_score[0]

# %%
data['best_caracteristic'] = data[data['nb_review']>0]["caracteristics_scores"].apply(best_caracteristic)

# %%
def show_best_caracteristic (data) :
    list_best_carac = []
    count_best_carac = Counter(data.apply(lambda x : x[0]))
    
    # Set the size of the figure
    fig, ax = plt.subplots(figsize=(10, 8))

    # Create a bar chart of the summed count of each word
    ax.bar(count_best_carac.keys(),count_best_carac.values())
    ax.set_xlabel('caracteristic')
    ax.set_ylabel('Count')
    ax.set_title('Summed Count of the best caracteristics')
    plt.show()

# %%
show_best_caracteristic(data[data['nb_review']>0]['best_caracteristic'])

# %%
def note_by_best_caracteristic (data):
    avg_note_carac = {"flavor" : 0, "long_lasting" : 0, "sweetness" : 0}
    for i in avg_note_carac.keys() : 
        avg_note_carac[i]  = data[data['best_caracteristic'].apply(lambda x : x[0])==i]['average_score'].mean()
    return avg_note_carac
    
avg_note_carac = note_by_best_caracteristic(data[data['nb_review']>0])
print(f"Average note with flavor as best caracteristic : {avg_note_carac['flavor']}.")
print(f"Average note with long_lasting as best caracteristic : {avg_note_carac['long_lasting']}.")
print(f"Average note with sweetness as best caracteristic : {avg_note_carac['sweetness']}.")
# Out:
# Average note with flavor as best caracteristic : 4.6258064516129025.
# Average note with long_lasting as best caracteristic : 4.425000000000001.
# Average note with sweetness as best caracteristic : 4.35.

# %%
def show_note_by_caracteristic (data,caracteristic):
    graph = {'x' : [],'y' : []}
    graph['x'] = list(data['caracteristics_scores'].apply(lambda x : x[caracteristic]))
    graph['y'] = list(data['average_score'])
    
    graph = sorted(graph.items(), key=lambda x: x[0], reverse=True)
    
    # Set the size of the figure
    fig, ax = plt.subplots(figsize=(10, 8))

    # Create a bar chart of the summed count of each word
    ax.scatter(graph[1][1],graph[0][1])
    ax.set_xlabel(caracteristic)
    ax.set_ylabel('Average article note')
    ax.set_title(f'Article note by {caracteristic} score')
    plt.show()

show_note_by_caracteristic(data[data['nb_review']>0],'flavor')
